# %% [markdown]
# # SAE Exploration Notebook
#
# Interactive exploration of gelu-2l residual stream SAEs.
# Core logic lives in `src/` — this notebook is for ad-hoc investigation only.

# %%
from src.data import load_model

model = load_model(device="cuda")
print(f"Model: {model.cfg.model_name}, d_model: {model.cfg.d_model}")
